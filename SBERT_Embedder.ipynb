# %%
import pandas as pd
import numpy as np
import torch
from tqdm.notebook import tqdm

# %%
wiki_es_2017 = pd.read_csv("enwiki.wikilink_graph.2017-03-01.csv/wikilink_graph.2017-03-01.csv", on_bad_lines = 'warn',delimiter="\t")

# %%
wiki_es_2017.shape
# Out:
# (150743638, 4)

# %%
import pickle
# Loading the seed 
with open('subsample_nodes.pkl', 'rb') as f:
    seed_nodes = pickle.load(f)

# %%
seed_nodes = set(map(eval, seed_nodes))

# %%
len(seed_nodes)
# Out:
# 1000000

# %%
# Sampling all the edges that are present in our random sample of nodes
edges = wiki_es_2017[(wiki_es_2017['page_id_from'].isin(seed_nodes)) & (wiki_es_2017['page_id_to'].isin(seed_nodes))]

# %%
edges.shape
# Out:
# (13595337, 4)

# %%
edges.head()
# Out:
#     page_id_from page_title_from  page_id_to            page_title_to
# 3             12       Anarchism    28357259  19th century philosophy
# 7             12       Anarchism      839656              Adolf Brand
# 8             12       Anarchism     2731583             Adolf Hitler
# 9             12       Anarchism      192008           Adolphe Thiers
# 11            12       Anarchism       30758     Age of Enlightenment

# %%
pageid_to_pagetitle = dict()
for page_id, page_title in zip(edges['page_id_from'], edges['page_title_from']):
    pageid_to_pagetitle[page_id] = page_title

# %%
for page_id, page_title in zip(edges['page_id_to'], edges['page_title_to']):
    pageid_to_pagetitle[page_id] = page_title

# %%
len(pageid_to_pagetitle)
# Out:
# 1000000

# %%
pageid_to_pagetitle
# Out:
# {12: 'Anarchism',
#  25: 'Autism',
#  39: 'Albedo',
#  290: 'A',
#  303: 'Alabama',
#  307: 'Abraham Lincoln',
#  308: 'Aristotle',
#  309: 'An American in Paris',
#  316: 'Academy Award for Best Production Design',
#  324: 'Academy Awards',
#  336: 'Altruism',
#  340: 'Alain Connes',
#  344: 'Allan Dwan',
#  358: 'Algeria',
#  573: 'Alchemy',
#  579: 'Alien',
#  580: 'Astronomer',
#  586: 'ASCII',
#  590: 'Austin (disambiguation)',
#  593: 'Animation',
#  594: 'Apollo',
#  599: 'Afroasiatic languages',
#  600: 'Andorra',
#  615: 'American Football Conference',
#  620: 'Animal Farm',
#  621: 'Amphibian',
#  624: 'Alaska',
#  628: 'Aldous Huxley',
#  630: 'Ada',
#  633: 'Algae',
#  640: 'Appellate procedure in the United States',
#  649: 'Arraignment',
#  651: 'America the Beautiful',
#  656: 'Acid',
#  659: 'American National Standards Institute',
#  666: 'Alkali metal',
#  668: 'Argument form',
#  670: 'Alphabet',
#  673: 'Atomic number',
#  676: 'Andrei Tarkovsky',
#  677: 'Ambiguity',
#  683: 'Adventure',
#  689: 'Asia',
#  690: 'Aruba',
#  691: 'Articles of Confederation',
#  698: 'Atlantic Ocean',
#  700: 'Arthur Schopenhauer',
#  701: 'Angola',
#  704: 'Demographics of Angola',
#  713: 'Android (robot)',
#  736: 'Albert Einstein',
#  740: 'Allah',
#  751: 'Aikido',
#  752: 'Art',
#  780: 'Atlas (disambiguation)',
#  785: 'Asteroids (video game)',
#  786: 'Asparagales',
#  788: 'Apiales',
#  789: 'Asterales',
#  800: 'Anime',
#  803: 'Arabic',
#  808: 'Alfred Hitchcock',
#  809: 'Anaconda',
#  841: 'Attila',
#  843: 'A Clockwork Orange (novel)',
#  844: 'Amsterdam',
#  851: 'Alfred Nobel',
#  852: 'Alexander Graham Bell',
#  863: 'American Civil War',
#  864: 'Andy Warhol',
#  868: 'Alp Arslan',
#  869: 'American Film Institute',
#  877: 'Abjad',
#  880: 'ABBA',
#  881: 'Allegiance',
#  887: 'MessagePad',
#  888: 'A. E. van Vogt',
#  890: 'Anna Kournikova',
#  897: 'Arsenic',
#  899: 'Actinium',
#  902: 'Atom',
#  904: 'Aluminium',
#  915: 'Andrey Markov',
#  921: 'Angst',
#  922: 'Anxiety',
#  928: 'Axiom',
#  929: 'Alpha',
#  931: 'The Amazing Spider-Man',
#  933: 'AM',
#  951: 'Antigua and Barbuda',
#  956: 'Asteraceae',
#  957: 'Apiaceae',
#  969: 'Ataxia',
#  981: 'Alps',
#  983: 'Albert Camus',
#  984: 'Agatha Christie',
#  986: 'The Plague',
#  988: 'Applied ethics',
#  991: 'Absolute value',
#  993: 'Analog signal',
#  1004: 'April',
#  1005: 'August',
#  1006: 'Aaron',
#  1008: 'April 6',
#  1009: 'April 12',
#  1010: 'April 15',
#  1013: 'August 27',
#  1021: 'Aspect ratio',
#  1023: 'Anarcho-capitalism',
#  1027: 'August 9',
#  1028: 'Aristophanes',
#  1030: 'Austrian School',
#  1032: 'Abscess',
#  1043: 'Northern cavefish',
#  1046: 'Abatement',
#  1057: 'Anatole France',
#  1064: 'Almond',
#  1074: 'Royal Antigua and Barbuda Defence Force',
#  1081: 'Economy of Azerbaijan',
#  1088: 'Azerbaijani Armed Forces',
#  1091: 'Geography of Armenia',
#  1092: 'Demographics of Armenia',
#  1093: 'Politics of Armenia',
#  1094: 'Economy of Armenia',
#  1098: 'Foreign relations of Armenia',
#  1130: 'Avicenna',
#  1134: 'Analysis',
#  1136: "America's National Game",
#  1146: 'Assembly line',
#  1148: 'Adelaide',
#  1154: 'August 2',
#  1158: 'Algebraic number',
#  1162: 'Accordion',
#  1164: 'Artificial intelligence',
#  1166: 'Afro Celt Sound System',
#  1171: 'Abbreviation',
#  1176: 'Antisymmetric relation',
#  1177: 'Aleister Crowley',
#  1184: 'Athene (disambiguation)',
#  1187: 'Alloy',
#  1196: 'Angle',
#  1198: 'Acoustics',
#  1200: 'Atomic physics',
#  1201: 'American Sign Language',
#  1202: 'Applet',
#  1209: 'Area',
#  1210: 'Astronomical unit',
#  1212: 'Artist',
#  1213: 'Actaeon',
#  1217: 'Anguilla',
#  1234: 'Acoustic theory',
#  1241: 'American (word)',
#  1245: 'Alpha ray',
#  1247: 'Alfonso Cuarón',
#  1259: 'August 3',
#  1260: 'Advanced Encryption Standard',
#  1271: 'Analytical Engine',
#  1286: 'List of Governors of Alabama',
#  1288: 'Apocrypha',
#  1291: 'Antarctic Treaty System',
#  1298: 'Ames, Iowa',
#  1303: 'Abdominal surgery',
#  1305: 'Abensberg',
#  1309: 'Almost all',
#  1312: 'Augustine',
#  1315: 'Abbey',
#  1316: 'Annales school',
#  1327: 'Antiparticle',
#  1334: 'April 16',
#  1335: 'Associative property',
#  1336: 'Apache Software Foundation',
#  1358: 'Anchor',
#  1360: 'Anazarbus',
#  1361: 'Anagram',
#  1362: 'Anadyr River',
#  1363: 'André-Marie Ampère',
#  1365: 'Ammonia',
#  1367: 'Albertosaurus',
#  1372: 'Amber',
#  1380: 'Alligatoridae',
#  1387: 'Alabaster',
#  1389: 'Ahab',
#  1400: 'Anno Domini',
#  1404: 'AV',
#  1416: 'April 29',
#  1418: 'Absolute zero',
#  1422: 'Amide',
#  1425: 'Antonio Vivaldi',
#  1437: 'Abraxas',
#  1441: 'Abydos (Hellespont)',
#  1449: 'Alan Kay',
#  1451: 'APL (programming language)',
#  1453: 'ALGOL',
#  1478: 'Álfheimr',
#  1482: 'Ask and Embla',
#  1490: 'August 17',
#  1504: 'Albert',
#  1525: 'Aspirin',
#  1526: 'Abner',
#  1528: 'Ahmed II',
#  1530: 'Ainu people',
#  1536: 'Acropolis',
#  1541: 'April 13',
#  1544: 'Agamemnon',
#  1546: 'Aga Khan III',
#  1551: 'Agis',
#  1558: 'American Chinese cuisine',
#  1560: 'Ahmad Shah Durrani',
#  1570: 'Alaric I',
#  1571: 'Alaric II',
#  1577: 'Alcaeus of Mytilene',
#  1580: 'Alcidamas',
#  1583: 'Ealdred (archbishop of York)',
#  1594: 'Alexander II of Scotland',
#  1595: 'Alexander I of Serbia',
#  1596: 'Alexander III of Scotland',
#  1597: 'Alexander of Greece (disambiguation)',
#  1603: 'Alexander II',
#  1605: 'Alexander Aetolus',
#  1606: 'Alexander Jannaeus',
#  1615: 'Alexios II Komnenos',
#  1616: 'Alexios III Angelos',
#  1623: 'Andrew Jackson',
#  1625: 'Aleksandr Solzhenitsyn',
#  1634: 'Aquaculture',
#  1640: 'Alfred the Great',
#  1644: 'Algiers',
#  1645: 'Ibn al-Haytham',
#  1647: 'Alessandro Allori',
#  1649: 'Almoravid dynasty',
#  1650: 'Aloe',
#  1653: 'Age of consent',
#  1654: 'Alypius of Antioch',
#  1656: 'Amalric of Bena',
#  1659: 'Afonso III of Portugal',
#  1662: 'Afonso VI of Portugal',
#  1676: 'Alfonso XII of Spain',
#  1686: 'Alfonso V of Aragon',
#  1687: 'Amathus',
#  1694: 'Alfonso IV',
#  1695: 'Amazons',
#  1701: 'Amazon River',
#  1702: 'Alfred of Beverley',
#  1710: 'April 22',
#  1717: 'Ambrosians',
#  1722: 'Ammon',
#  1724: 'Ammonius Saccas',
#  1726: 'Book of Amos',
#  1728: 'Amram',
#  1734: 'Anah',
#  1735: 'Ananda',
#  1737: 'Anaxagoras',
#  1746: 'Anaximenes of Lampsacus',
#  1747: 'Anastasius',
#  1755: 'Andrew II of Hungary',
#  1756: 'An Enquiry Concerning Human Understanding',
#  1758: 'André de Longjumeau',
#  1759: 'Andriscus',
#  1762: 'Andronikos I Komnenos',
#  1764: 'Andronicus of Rhodes',
#  1765: 'Andronicus',
#  1767: 'Ammianus Marcellinus',
#  1770: 'Apollo 13',
#  1777: 'April 2',
#  1778: 'Acetylene',
#  1779: 'Alfred',
#  1789: 'Apuleius',
#  1791: 'Anti-ballistic missile',
#  1797: 'Acre',
#  1806: 'Arnold Schwarzenegger',
#  1812: 'Amway',
#  1814: 'Adam Smith',
#  1827: 'April 23',
#  1832: 'Allomorph',
#  1834: 'Allophone',
#  1835: 'Affix',
#  1837: 'Allegory',
#  1839: 'Allotropy',
#  1845: 'Alternative medicine',
#  1847: 'Archimedean solid',
#  1859: 'Arizona State University',
#  1862: 'April 14',
#  1866: 'Alarums and Excursions',
#  1879: 'Alfonso Jordan',
#  1890: 'American English',
#  1893: 'Albert Spalding',
#  1897: 'Australian English',
#  1902: 'American Airlines Flight 77',
#  1911: 'Allele',
#  1912: 'Ampicillin',
#  1914: 'Antimicrobial resistance',
#  1915: 'Antigen',
#  1919: 'Antwerp (disambiguation)',
#  1920: 'Aquila',
#  1924: 'Argo Navis',
#  1926: 'Antlia',
#  1927: 'Ara (constellation)',
#  1930: 'Arkansas',
#  1938: 'Andrew Carnegie',
#  1941: 'Aeon',
#  1943: 'Australian Democrats',
#  1950: 'American Civil Liberties Union',
#  1957: 'Alexander Technique',
#  1965: 'Apollo 1',
#  1966: 'Apollo 10',
#  1967: 'Apollo 12',
#  1974: 'April 17',
#  1979: 'Alpha Centauri',
#  1980: 'Amiga',
#  1986: 'Actinophryid',
#  1997: 'Algebraic geometry',
#  1998: 'Austin, Texas',
#  2003: 'Argument from morality',
#  2006: 'Auschwitz concentration camp',
#  2018: 'A. J. Ayer',
#  2019: 'André Weil',
#  2020: 'Achaeans (Homer)',
#  2030: 'Augustine of Hippo',
#  2032: 'Acting',
#  2053: 'Advance Australia Fair',
#  2061: 'Automatic number announcement circuit',
#  2065: 'Auguste Rodin',
#  2067: 'Ann Arbor, Michigan',
#  2070: 'Act of Settlement 1701',
#  2075: 'Aircraft hijacking',
#  2083: 'Auguste and Louis Lumière',
#  2084: 'Acts of the Apostles',
#  2088: 'Aphasia',
#  2099: 'Andrew Tridgell',
#  2101: 'Asterix',
#  2104: 'Heathenry in the United States',
#  2108: 'Adalbert of Prague',
#  2116: 'Apple II series',
#  2117: 'Apple III',
#  2118: 'AVL tree',
#  2122: 'Astrology',
#  2134: 'Ark of the Covenant',
#  2138: 'Arthur Wellesley',
#  2140: 'Atlanta Braves',
#  2141: 'Atari ST',
#  2147: 'Armour',
#  2148: 'Armoured fighting vehicle',
#  2151: 'Anton Drexler',
#  2161: 'Artistic License',
#  2170: 'ABCD',
#  2171: 'Anti-realism',
#  2174: 'Arsenal F.C.',
#  2175: 'Cuisine of the United States',
#  2176: 'Ahmad Shah Massoud',
#  2186: 'Armadillo',
#  2192: 'August 11',
#  2193: 'Arcology',
#  2194: 'April 5',
#  2196: 'April 19',
#  2197: 'Amstrad CPC',
#  2204: 'Arabic alphabet',
#  2208: 'Arctic fox',
#  2219: 'Aircraft carrier',
#  2221: 'Apicomplexa',
#  2222: 'Argentine cuisine',
#  2224: 'April 8',
#  2226: 'Ad hominem',
#  2238: 'Antipope John XXIII',
#  2245: 'Annapolis Valley',
#  2257: 'Apostolic succession',
#  2264: 'List of Anglo-Saxon monarchs and kingdoms',
#  2275: 'Apple II',
#  2279: 'April 3',
#  2282: 'Alexis Korner',
#  2286: 'Tank destroyer',
#  2287: 'Armored car (military)',
#  2288: 'Self-propelled anti-aircraft weapon',
#  2299: 'American Media, Inc.',
#  2303: 'Aramaic language',
#  2308: 'Actinide',
#  2310: 'Arthur Miller',
#  2313: 'Anton Diabelli',
#  2316: 'Audio file format',
#  2321: 'Area 51',
#  2323: "Amdahl's law",
#  2330: 'Abbe number',
#  2338: 'Rise and Fall of the City of Mahagonny',
#  2345: 'Archbishop of Canterbury',
#  2349: 'Abstract data type',
#  2357: 'American Football League',
#  2360: 'Abu Nidal Organization',
#  2363: 'Alessandro Scarlatti',
#  2371: 'Albert Pike',
#  2380: 'Accelerated Graphics Port',
#  2382: 'Aalen',
#  2388: 'Antidepressant',
#  2389: 'Auger effect',
#  2393: 'Analog television',
#  2396: 'Adhesive',
#  2405: 'Aon (company)',
#  2406: 'Alban Berg',
#  2411: 'A cappella',
#  2414: 'Arrangement',
#  2416: 'Athanasian Creed',
#  2422: 'Ann Widdecombe',
#  2425: 'Aurangzeb',
#  2431: 'Minute and second of arc',
#  2433: 'Alberto Giacometti',
#  2447: 'Anton Chekhov',
#  2466: 'Aarau',
#  2467: 'Canton of Aargau',
#  2470: 'Aba',
#  2472: 'American Quarter Horse',
#  2475: 'Abadeh',
#  2477: 'Abakan',
#  2482: 'Arc de Triomphe',
#  2493: 'Anthroposophy',
#  2494: 'Aurochs',
#  2500: 'Anus',
#  2502: 'Acantharea',
#  2503: 'African National Congress',
#  2504: 'Amphetamine',
#  2506: 'Asynchronous communication',
#  2508: 'Artillery',
#  2524: 'Airbus A300',
#  2536: 'Articolo 31',
#  2543: 'Alexander Kerensky',
#  2560: 'Administrative law',
#  2564: 'April 10',
#  2583: 'Arbroath Abbey',
#  2593: 'Accounting',
#  2613: 'George Abbot (bishop)',
#  2616: 'Adware',
#  2623: 'Aegadian Islands',
#  2624: 'Aegean civilizations',
#  2627: 'Aegina',
#  2629: 'Aegisthus',
#  2637: 'Atomic absorption spectroscopy',
#  2639: 'Arthur St. Clair',
#  2640: 'Ajaccio',
#  2645: 'Ajmer',
#  2646: 'Ajmer-Merwara',
#  2653: 'Abatement of freehold',
#  2662: 'Affiliation (family law)',
#  2665: 'Affray',
#  2671: 'Abbahu',
#  2676: 'Abd al-Rahman I',
#  2678: 'Abd-ar-Rahman III',
#  2679: 'Abd ar-Rahman IV',
#  2681: 'Abdülaziz',
#  2684: 'Abdera, Spain',
#  2686: 'Apollos',
#  2689: 'Antacid',
#  2695: 'Abdur Rahman Khan',
#  2701: 'Aberdare',
#  2703: 'Aberration of light',
#  2704: 'Optical aberration',
#  2709: 'Aberdeen, South Dakota',
#  2712: 'Aberdour',
#  2722: 'Anders Celsius',
#  2723: 'Adam Carolla',
#  2724: 'Autocorrelation',
#  2726: 'Atlas Autocode',
#  2740: 'Abiathar',
#  2745: 'Azad Kashmir',
#  2761: 'Alkene',
#  2763: 'Alkyne',
#  2767: 'ACE inhibitor',
#  2769: 'Antianginal',
#  2770: 'Anatomical Therapeutic Chemical Classification System',
#  2779: 'Atari 2600',
#  2780: 'Atari 5200',
#  2782: 'Atari Jaguar',
#  2783: 'Atari Lynx',
#  2786: 'Andrei Sakharov',
#  2787: 'Astrobiology',
#  2790: 'Air show',
#  2802: 'Akihabara',
#  2812: 'Aron Nimzowitsch',
#  2813: 'Aragonese language',
#  2815: 'Advanced Mobile Phone System',
#  2820: 'Andreas Schlüter',
#  2822: 'Ash',
#  2823: 'Antiderivative',
#  2827: 'Abingdon',
#  2830: 'Abjuration',
#  2839: 'Angular momentum',
#  2847: 'Aung San Suu Kyi',
#  2851: 'Abraham Joshua Heschel',
#  2856: 'Latin American Integration Association',
#  2861: 'Advertising',
#  2865: 'Andrzej Sapkowski',
#  2866: 'Ammeter',
#  2870: 'Antipsychotic',
#  2877: 'Augustine of Canterbury',
#  2885: 'Amoxicillin',
#  2893: 'Alex Lifeson',
#  2900: 'File archiver',
#  2905: 'Artemis',
#  2906: 'Arbeit macht frei',
#  2909: 'Albinism',
#  2923: 'AIM (software)',
#  2935: 'ANS',
#  2939: 'Interior Alaska',
#  2940: 'And did those feet in ancient time',
#  2941: 'The Bush (Alaska)',
#  2944: 'Ariel Sharon',
#  2947: 'Anoa',
#  2948: 'Agner Krarup Erlang',
#  2952: 'Alcopop',
#  2955: 'Alkali',
#  2957: 'AMOS (programming language)',
#  2959: 'Arcadia 2001',
#  2963: 'Assassination',
#  2975: 'Anti-Ballistic Missile Treaty',
#  2983: 'Austria-Hungary',
#  2988: 'Admiralty',
#  3013: 'Ann Druyan',
#  3020: 'Ambrose of Alexandria',
#  3027: 'Anubis',
#  3029: 'Arthur Jensen',
#  3036: 'Adoptionism',
#  3038: 'Acid–base reaction',
#  3040: 'Abu al-Faraj al-Isfahani',
#  3046: 'Amyl nitrite',
#  3049: 'Autumn',
#  3052: 'Alameda, California',
#  3055: 'Accrington',
#  3058: 'Armageddon',
#  3068: 'Muslim conquests of Afghanistan',
#  3080: 'Alexandria',
#  3085: 'Alexandria Troas',
#  3088: 'Alexandria, Romania',
#  3092: 'Akira Toriyama',
#  3093: 'Epsilon Ursae Majoris',
#  3095: 'Amiga 500',
#  3107: 'Asymptote',
#  3116: 'Accumulator (computing)',
#  3118: 'Arithmetic',
#  3123: 'Amakusa',
#  3132: 'Adolphe Sax',
#  3134: 'Aspirated consonant',
#  3144: "A Doll's House",
#  3146: 'AIM-7 Sparrow',
#  3147: 'AIM-120 AMRAAM',
#  3149: 'AGM-88 HARM',
#  3152: 'AIM-54 Phoenix',
#  3155: 'Lockheed AC-130',
#  3158: 'Alternative',
#  3172: 'ANSI C',
#  3173: 'Alien and Sedition Acts',
#  3189: 'Ascending chain condition',
#  3192: 'Adin Steinsaltz',
#  3198: 'A. E. Housman',
#  3212: 'Al Capone',
#  3217: 'Army of Darkness',
#  3218: 'RUR-5 ASROC',
#  3225: 'Athanasius of Alexandria',
#  3226: 'Azores',
#  3229: 'Outback',
#  3233: 'Acceptance testing',
#  3237: 'National Alliance (Italy)',
#  3270: 'Albert III, Duke of Saxony',
#  3292: 'Brass',
#  3295: 'Bonn',
#  3333: 'The Birth of a Nation',
#  3335: 'Baltic Sea',
#  3343: 'Belgium',
#  3352: 'Blues',
#  3353: 'Bluegrass',
#  3360: 'Bar (disambiguation)',
#  3364: 'Bit',
#  3370: 'Boron nitride',
#  3371: 'Bach (disambiguation)',
#  3374: 'Blood on the Tracks',
#  3375: 'Love and Theft (Bob Dylan album)',
#  3386: 'Black Sea',
#  3392: 'British Columbia',
#  3395: 'Gautama Buddha',
#  3397: 'Bridge',
#  3398: 'Beadwork',
#  3406: 'Branchiopoda',
#  3408: 'Baruch Spinoza',
#  3409: 'Being',
#  3411: '...Baby One More Time (album)',
#  3416: 'Bryozoa',
#  3421: 'Basis',
#  3427: 'Beavis and Butt-Head',
#  3428: 'Bromeliales',
#  3429: 'Brassicales',
#  3436: 'Symphony No. 9 (Beethoven)',
#  3438: 'Piano Trios, Op. 70 (Beethoven)',
#  3441: 'Violin Sonata No. 5 (Beethoven)',
#  3443: 'Barratry (common law)',
#  3447: 'Cue sports',
#  3455: 'Barbados',
#  3456: 'Bassas da India',
#  3457: 'Belarus',
#  3458: 'Belize',
#  3459: 'Benin',
#  3462: 'Bolivia',
#  3464: 'Botswana',
#  3514: 'Government of Barbados',
#  3545: 'Telecommunications in Belgium',
#  3613: 'Geography of Botswana',
#  3618: 'Transport in Botswana',
#  3633: 'Politics of Brazil',
#  3636: 'Transport in Brazil',
#  3637: 'Brazilian Armed Forces',
#  3671: 'Economy of Bulgaria',
#  3673: 'Transport in Bulgaria',
#  3683: 'Military of Burkina Faso',
#  3701: 'Military of Burundi',
#  3711: 'Bell (disambiguation)',
#  3712: 'Bell Labs',
#  3713: 'Bjarne Stroustrup',
#  3717: 'Brain',
#  3728: 'Bass music',
#  3733: 'Bhangra (music)',
#  3735: 'Beastie Boys',
#  3736: 'British Isles',
#  3740: 'Björn Ulvaeus',
#  3741: 'Benny Andersson',
#  3742: 'Bluetooth',
#  3746: 'Blade Runner',
#  3747: 'Bill Gates',
#  3751: 'Belgian Blue',
#  3755: 'Boron',
#  3756: 'Bromine',
#  3764: 'Bavaria',
#  3772: 'BMW',
#  3777: 'Bay (disambiguation)',
#  3778: 'Book',
#  3785: 'Bille August',
#  3789: 'Bitola',
#  3794: 'Brassicaceae',
#  3800: 'At bat',
#  3806: 'Hit by pitch',
#  3807: 'Hit (baseball)',
#  3808: 'On-base percentage',
#  3809: 'Sacrifice fly',
#  3810: 'On-base plus slugging',
#  3811: 'Stolen base',
#  3814: 'Games played',
#  3823: 'Binary',
#  3826: 'Bumin Qaghan',
#  3827: 'Bilge Khagan',
#  3832: 'Bauhaus',
#  3838: 'Bruce Sterling',
#  3846: 'Banjo',
#  3850: 'Baseball',
#  3856: 'History of baseball in the United States',
#  3859: 'Major League Baseball Rookie of the Year Award',
#  3860: 'National League Championship Series',
#  3861: 'American League Championship Series',
#  3862: 'American League Division Series',
#  3864: '2001 World Series',
#  3869: 'Bruce Perens',
#  3914: 'British and Irish Lions',
#  3921: 'Basketball',
#  3928: 'Ball',
#  3931: 'Binary relation',
#  3940: 'Blowfish (cipher)',
#  3954: 'Biochemistry',
#  3957: 'Baroque',
#  3959: 'Boolean algebra (structure)',
#  3962: 'British',
#  3963: 'Beachcomber (pen name)',
#  3968: 'Bodhisattva',
#  3969: 'Buckingham Palace',
#  3970: 'British Airways',
#  3972: 'Bicycling',
#  3974: 'Biopolymer',
#  3978: 'Book of Mormon',
#  3981: 'Blackjack',
#  3982: 'Bicarbonate',
#  3986: 'Benjamin Franklin',
#  3992: 'Bram Stoker',
#  3996: 'Boat',
#  3997: 'Blood',
#  3999: 'Benoit Mandelbrot',
#  4003: 'Beaumarchais',
#  4010: 'Bing Crosby',
#  4012: 'Basel Convention',
#  4015: 'BASIC',
#  4016: 'List of Byzantine emperors',
#  4024: 'Butterfly effect',
#  4031: 'Buckminster Fuller',
#  4032: 'Bill Watterson',
#  4035: 'Black',
#  4037: 'Bletchley Park',
#  4052: 'BCPL',
#  4054: 'Battleship',
#  4057: 'Battlecruiser',
#  4059: 'Bob Hawke',
#  4060: 'Baldr',
#  4063: 'Brísingamen',
#  4067: 'Bragi',
#  4068: 'Blaise Pascal',
#  4077: 'Binary prefix',
#  4079: 'BPP (complexity)',
#  4080: 'BQP',
#  4091: 'Bartolomeo Ammannati',
#  4097: 'Bordeaux',
#  4098: 'Puzzle Bobble',
#  4099: 'Bone',
#  4100: 'Bretwalda',
#  4101: 'Brouwer fixed-point theorem',
#  4106: 'Benzoic acid',
#  4113: 'Bouldering',
#  4122: 'B roll',
#  4146: 'Bus',
#  4157: 'Brown University',
#  4163: 'Bertrand Russell',
#  4165: 'Boeing 767',
#  4173: 'Babe Ruth',
#  4179: 'British English',
#  4181: 'Battle',
#  4183: 'Botany',
#  4193: 'Common buzzard',
#  4195: 'Barbara Olson',
#  4196: "Barnard's Star",
#  4213: 'Baltic languages',
#  4218: 'North American B-25 Mitchell',
#  4227: 'Barry Lyndon',
#  4231: 'Buffy the Vampire Slayer (film)',
#  4233: 'Berthe Morisot',
#  4237: 'Barnard College',
#  4240: 'Order of Saint Benedict',
#  4241: 'Bayezid I',
#  4248: 'Bowls',
#  4249: 'Barcelonnette',
#  4251: "Bahá'í Faith",
#  4267: 'Belle and Sebastian',
#  4285: 'Bodhidharma',
#  4293: 'Baltimore Ravens',
#  4300: 'Bocce',
#  4312: 'Bethlehem',
#  4319: 'Books of Chronicles',
#  4321: 'Binary tree',
#  4329: 'Backgammon',
#  4332: 'Book of Ezra',
#  4335: 'Batman',
#  4340: 'Baltimore Orioles',
#  4345: 'Bohemia',
#  4352: 'Backplane',
#  4356: 'Battle of Waterloo',
#  4359: 'Boomerang',
#  4361: 'Biological warfare',
#  4364: 'Book of Isaiah',
#  4365: 'Bilinear map',
#  4366: 'Blind Blake',
#  4367: 'Brian Lara',
#  4368: 'Beagle',
#  4375: 'Barry Bonds',
#  4376: 'Book of Numbers',
#  4379: 'Book of Revelation',
#  4381: 'Book of Ruth',
#  4384: 'Rail transport in Great Britain',
#  4385: 'British Rail',
#  4388: 'Book of Proverbs',
#  4390: 'Book of Ezekiel',
#  4392: 'Bristol City F.C.',
#  4393: 'Bioterrorism',
#  4396: 'Northrop Grumman B-2 Spirit',
#  4400: 'Bear',
#  4401: 'Bald eagle',
#  4402: 'Brown bear',
#  4405: 'Biathlon',
#  4407: 'Bubble and squeak',
#  4419: 'Breast reconstruction',
#  4436: 'Brownian motion',
#  4444: 'Bandy',
#  4446: 'Booker Prize',
#  4449: 'Book of Hosea',
#  4450: 'Book of Obadiah',
#  4451: 'Book of Jonah',
#  4452: 'Book of Micah',
#  4454: 'Book of Haggai',
#  4455: 'Book of Malachi',
#  4456: 'Book of Zechariah',
#  4457: 'Book of Zephaniah',
#  4459: 'Backward compatibility',
#  4462: 'Blue crane',
#  4471: 'Billy Bob Thornton',
#  4472: 'The Big O',
#  4477: 'The Beach Boys',
#  4481: 'Beatrix Potter',
#  4485: 'Bakelite',
#  4487: 'Bean',
#  4489: 'Breast',
#  4492: 'Baghdad',
#  4495: 'British thermal unit',
#  4499: 'Band',
#  4503: 'Battle of Poitiers',
#  4506: 'Bongo (antelope)',
#  4513: 'Banshee',
#  4518: 'Borneo',
#  4519: 'Ballpoint pen',
#  4526: 'Brick',
#  4527: 'Béla Bartók',
#  4528: 'Bill Haley',
#  4529: 'Northern bobwhite',
#  4531: 'Bipolar disorder',
#  4536: 'Blitz',
#  4540: 'Balts',
#  4542: 'Bra–ket notation',
#  4544: 'Blind Willie McTell',
#  4545: 'BDSM',
#  4550: 'Bikini',
#  4552: 'Bernard of Clairvaux',
#  4560: 'Braveheart',
#  4561: 'Brian Aldiss',
#  4565: 'Bambara language',
#  4566: 'Baku',
#  4567: 'Balalaika',
#  4568: 'Bank of China Tower (Hong Kong)',
#  4575: 'Ballad',
#  4579: 'Blue Öyster Cult',
#  4580: 'Battery Park City',
#  4581: 'Bacterial vaginosis',
#  4582: 'Bud Selig',
#  4583: 'Bison',
#  4592: 'Basic Role-Playing',
#  4595: 'Wireless broadband',
#  4601: 'Björn Borg',
#  4606: 'Battle of the Nile',
#  4607: 'Barnabas',
#  4608: 'Birka',
#  4615: 'Battle of Agincourt',
#  4620: 'Bronze Age',
#  4621: 'BBC News (TV channel)',
#  4622: 'Bill Oddie',
#  4626: 'Broadway (Manhattan)',
#  4651: 'Beta decay',
#  4652: 'Blitzkrieg',
#  4654: 'Bee',
#  4660: 'Basques',
#  4662: 'Bookkeeping',
#  4664: 'Bézier curve',
#  4665: 'Banach algebra',
#  4670: 'Bruce Campbell',
#  4671: 'Baron Aberdare',
#  4673: 'Boy band',
#  4674: 'B-tree',
#  4691: 'Big Apple',
#  4693: 'Berber languages',
#  4702: 'Brahui language',
#  4715: 'Boolean satisfiability problem',
#  4717: 'Bob Jones University',
#  4721: 'British Empire',
#  4728: 'Batman Returns',
#  4729: 'Batman & Robin (film)',
#  4737: 'Brownie McGhee',
#  4741: 'Bayonne',
#  4748: 'Baudot code',
#  4749: 'Blu Tack',
#  4751: 'Bacillus',
#  4754: 'Blue Streak (missile)',
#  4757: 'Bestiary',
#  4768: 'Brit milah',
#  4775: 'British Standards',
#  4778: 'Branch Davidians',
#  4781: 'Benzodiazepine',
#  4788: 'Body mass index',
#  4796: 'Bladder (disambiguation)',
#  4800: 'Babylon 5',
#  4810: 'Balance of trade',
#  4819: 'Balfour Declaration of 1926',
#  4820: 'Balfour Declaration',
#  4829: 'Balkans',
#  4836: 'Barış Manço',
#  4840: 'Blitz BASIC',
#  4845: 'Blood alcohol content',
#  4851: 'Budweiser',
#  4855: 'Basso continuo',
#  4856: 'Borough',
#  4859: 'Bodmin Moor',
#  4860: 'Berkeley, California',
#  4862: 'Bengal',
#  4865: 'Roman Breviary',
#  4868: 'B. F. Skinner',
#  4869: 'Bill',
#  4870: 'Bill Macy',
#  4875: 'Bin Laden (disambiguation)',
#  4876: 'Blizzard Entertainment',
#  4878: 'Robert Bellarmine',
#  4880: 'Bildungsroman',
#  4881: 'Bachelor',
#  4887: 'British Army',
#  4893: 'Bob Costas',
#  4906: 'Beta sheet',
#  4913: 'Black Russian',
#  4921: 'Bacardi',
#  4924: 'Bunsen burner',
#  4925: 'Blue whale',
#  4927: 'Bolsheviks',
#  4934: 'Basic English',
#  4940: 'Brass instrument',
#  4941: 'Blood libel',
#  4942: 'Bagpuss',
#  4950: 'Born again',
#  4953: 'Book of Common Prayer',
#  4961: 'Bovril',
#  4963: 'Benjamin D. Santer',
#  4965: 'Bubble Bobble',
#  4967: 'Blackwood convention',
#  4969: 'Bill Bixby',
#  4972: 'Bronze Star Medal',
#  4973: 'Ballarat',
#  4975: 'Battle of Abritus',
#  4978: 'Battle of Berestechko',
#  4988: 'Brezhnev Doctrine',
#  4996: 'Brabham',
#  4997: 'Boeing B-17 Flying Fortress',
#  5001: 'Bathyscaphe Trieste',
#  5008: 'Battle of Actium',
#  5014: 'Bistability',
#  5020: 'Banda Islands',
#  5022: 'B.F. Skinner',
#  5033: 'Bo Diddley',
#  5038: 'List of Olympic medalists in biathlon',
#  5039: 'Biathlon World Championships',
#  5040: 'Inedia',
#  5046: 'Belfast',
#  5047: 'Biotite',
#  5049: 'Burns supper',
#  5050: 'Bill Bryson',
#  5052: 'Bentley',
#  5131: 'Chordate',
#  5134: 'Chess',
#  5142: 'Charlie Chaplin',
#  5165: 'Country',
#  5170: 'Combinatorics',
#  5176: 'Calculus',
#  5180: 'Chemistry',
#  5184: 'Cytoplasm',
#  5188: 'Central Europe',
#  5194: 'Politics of Canada',
#  5206: 'Computer-generated art',
#  5213: 'Computing',
#  5215: 'Casino',
#  5216: 'Khmer language',
#  5221: 'Carnivora',
#  5224: 'Citizen Kane',
#  5229: 'Callitrichidae',
#  5230: 'Cebidae',
#  5236: 'Coast',
#  5244: 'Cipher',
#  5252: 'Lists of universities and colleges',
#  5253: 'Constitution',
#  5254: 'Common law',
#  5255: 'Civil law',
#  5257: 'Court of appeals (disambiguation)',
#  5267: 'Constellation',
#  5270: 'Car (disambiguation)',
#  5272: 'Printer (computing)',
#  5282: 'Catalan language',
#  5291: 'Computer games',
#  5292: 'Collectable card games',
#  5302: 'Conditional',
#  5304: 'Cone (disambiguation)',
#  5310: 'Personal computer hardware',
#  5312: 'The Consolation of Philosophy',
#  5314: 'Charlemagne',
#  5322: 'Czechoslovakia',
#  5323: 'Computer science',
#  5326: 'Creationism',
#  5331: 'Demographics of Chad',
#  5334: 'Telecommunications in Chad',
#  5335: 'Transport in Chad',
#  5337: 'Foreign relations of Chad',
#  5346: 'Colloid',
#  5355: 'Cooking',
#  5362: 'Casino game',
#  5367: 'Cambrian',
#  5369: 'Contraception',
#  5378: 'Physical cosmology',
#  5382: 'Inflation (cosmology)',
#  5385: 'Candela',
#  5387: 'Condensed matter physics',
#  5390: 'Conversion of units',
#  5395: 'Chives',
#  5397: 'Chris Morris (satirist)',
#  5399: 'Colorado',
#  5401: 'Carboniferous',
#  5407: 'California',
#  5408: 'Columbia River',
#  5409: 'Commelinales',
#  5413: 'Coin collecting',
#  5422: 'Capcom',
#  5430: 'Demographics of Cambodia',
#  5431: 'Politics of Cambodia',
#  5434: 'Transport in Cambodia',
#  5460: 'Geography of Cape Verde',
#  5462: 'Politics of Cape Verde',
#  5467: 'Foreign relations of Cape Verde',
#  5468: 'Cayman Islands',
#  5478: 'Central African Republic',
#  5486: 'Central African Armed Forces',
#  5487: 'Foreign relations of the Central African Republic',
#  5489: 'Chile',
#  5498: 'Foreign relations of Chile',
#  5530: 'Conspiracy theory',
#  5552: 'History of Costa Rica',
#  ...}

# %%
pageid_to_nodeid = {k:idx for idx,k in enumerate(pageid_to_pagetitle.keys())}

# %%
nodeid_to_pageid = {v:k for k,v in pageid_to_nodeid.items()}

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
embeddings = model.encode(list(pageid_to_pagetitle.values()))

# %%
x = torch.tensor(embeddings)

# %%
x.size()
# Out:
# torch.Size([1000000, 384])

# %%
id_from = [pageid_to_nodeid[i] for i in edges['page_id_from']] 
id_to = [pageid_to_nodeid[i] for i in edges['page_id_to']]

# %%
edge_index = torch.tensor([id_from,id_to])

# %%
edge_index
# Out:
# tensor([[     0,      0,      0,  ..., 926146, 926146, 926146],
#         [619578,  83144, 174547,  ..., 159732,   5859,  32182]])

# %%
pageid_to_nodeid[28357259]
# Out:
# 619578

# %%
titles = [[pageid_to_pagetitle[nodeid_to_pageid[i]]] for i in range(1_000_000)]

# %%
titles
# Out:
# [['Anarchism'],
#  ['Autism'],
#  ['Albedo'],
#  ['A'],
#  ['Alabama'],
#  ['Abraham Lincoln'],
#  ['Aristotle'],
#  ['An American in Paris'],
#  ['Academy Award for Best Production Design'],
#  ['Academy Awards'],
#  ['Altruism'],
#  ['Alain Connes'],
#  ['Allan Dwan'],
#  ['Algeria'],
#  ['Alchemy'],
#  ['Alien'],
#  ['Astronomer'],
#  ['ASCII'],
#  ['Austin (disambiguation)'],
#  ['Animation'],
#  ['Apollo'],
#  ['Afroasiatic languages'],
#  ['Andorra'],
#  ['American Football Conference'],
#  ['Animal Farm'],
#  ['Amphibian'],
#  ['Alaska'],
#  ['Aldous Huxley'],
#  ['Ada'],
#  ['Algae'],
#  ['Appellate procedure in the United States'],
#  ['Arraignment'],
#  ['America the Beautiful'],
#  ['Acid'],
#  ['American National Standards Institute'],
#  ['Alkali metal'],
#  ['Argument form'],
#  ['Alphabet'],
#  ['Atomic number'],
#  ['Andrei Tarkovsky'],
#  ['Ambiguity'],
#  ['Adventure'],
#  ['Asia'],
#  ['Aruba'],
#  ['Articles of Confederation'],
#  ['Atlantic Ocean'],
#  ['Arthur Schopenhauer'],
#  ['Angola'],
#  ['Demographics of Angola'],
#  ['Android (robot)'],
#  ['Albert Einstein'],
#  ['Allah'],
#  ['Aikido'],
#  ['Art'],
#  ['Atlas (disambiguation)'],
#  ['Asteroids (video game)'],
#  ['Asparagales'],
#  ['Apiales'],
#  ['Asterales'],
#  ['Anime'],
#  ['Arabic'],
#  ['Alfred Hitchcock'],
#  ['Anaconda'],
#  ['Attila'],
#  ['A Clockwork Orange (novel)'],
#  ['Amsterdam'],
#  ['Alfred Nobel'],
#  ['Alexander Graham Bell'],
#  ['American Civil War'],
#  ['Andy Warhol'],
#  ['Alp Arslan'],
#  ['American Film Institute'],
#  ['Abjad'],
#  ['ABBA'],
#  ['Allegiance'],
#  ['MessagePad'],
#  ['A. E. van Vogt'],
#  ['Anna Kournikova'],
#  ['Arsenic'],
#  ['Actinium'],
#  ['Atom'],
#  ['Aluminium'],
#  ['Andrey Markov'],
#  ['Angst'],
#  ['Anxiety'],
#  ['Axiom'],
#  ['Alpha'],
#  ['The Amazing Spider-Man'],
#  ['AM'],
#  ['Antigua and Barbuda'],
#  ['Asteraceae'],
#  ['Apiaceae'],
#  ['Ataxia'],
#  ['Alps'],
#  ['Albert Camus'],
#  ['Agatha Christie'],
#  ['The Plague'],
#  ['Applied ethics'],
#  ['Absolute value'],
#  ['Analog signal'],
#  ['April'],
#  ['August'],
#  ['Aaron'],
#  ['April 6'],
#  ['April 12'],
#  ['April 15'],
#  ['August 27'],
#  ['Aspect ratio'],
#  ['Anarcho-capitalism'],
#  ['August 9'],
#  ['Aristophanes'],
#  ['Austrian School'],
#  ['Abscess'],
#  ['Northern cavefish'],
#  ['Abatement'],
#  ['Anatole France'],
#  ['Almond'],
#  ['Royal Antigua and Barbuda Defence Force'],
#  ['Economy of Azerbaijan'],
#  ['Azerbaijani Armed Forces'],
#  ['Geography of Armenia'],
#  ['Demographics of Armenia'],
#  ['Politics of Armenia'],
#  ['Economy of Armenia'],
#  ['Foreign relations of Armenia'],
#  ['Avicenna'],
#  ['Analysis'],
#  ["America's National Game"],
#  ['Assembly line'],
#  ['Adelaide'],
#  ['August 2'],
#  ['Algebraic number'],
#  ['Accordion'],
#  ['Artificial intelligence'],
#  ['Afro Celt Sound System'],
#  ['Abbreviation'],
#  ['Antisymmetric relation'],
#  ['Aleister Crowley'],
#  ['Athene (disambiguation)'],
#  ['Alloy'],
#  ['Angle'],
#  ['Acoustics'],
#  ['Atomic physics'],
#  ['American Sign Language'],
#  ['Applet'],
#  ['Area'],
#  ['Astronomical unit'],
#  ['Artist'],
#  ['Actaeon'],
#  ['Anguilla'],
#  ['Acoustic theory'],
#  ['American (word)'],
#  ['Alpha ray'],
#  ['Alfonso Cuarón'],
#  ['August 3'],
#  ['Advanced Encryption Standard'],
#  ['Analytical Engine'],
#  ['List of Governors of Alabama'],
#  ['Apocrypha'],
#  ['Antarctic Treaty System'],
#  ['Ames, Iowa'],
#  ['Abdominal surgery'],
#  ['Abensberg'],
#  ['Almost all'],
#  ['Augustine'],
#  ['Abbey'],
#  ['Annales school'],
#  ['Antiparticle'],
#  ['April 16'],
#  ['Associative property'],
#  ['Apache Software Foundation'],
#  ['Anchor'],
#  ['Anazarbus'],
#  ['Anagram'],
#  ['Anadyr River'],
#  ['André-Marie Ampère'],
#  ['Ammonia'],
#  ['Albertosaurus'],
#  ['Amber'],
#  ['Alligatoridae'],
#  ['Alabaster'],
#  ['Ahab'],
#  ['Anno Domini'],
#  ['AV'],
#  ['April 29'],
#  ['Absolute zero'],
#  ['Amide'],
#  ['Antonio Vivaldi'],
#  ['Abraxas'],
#  ['Abydos (Hellespont)'],
#  ['Alan Kay'],
#  ['APL (programming language)'],
#  ['ALGOL'],
#  ['Álfheimr'],
#  ['Ask and Embla'],
#  ['August 17'],
#  ['Albert'],
#  ['Aspirin'],
#  ['Abner'],
#  ['Ahmed II'],
#  ['Ainu people'],
#  ['Acropolis'],
#  ['April 13'],
#  ['Agamemnon'],
#  ['Aga Khan III'],
#  ['Agis'],
#  ['American Chinese cuisine'],
#  ['Ahmad Shah Durrani'],
#  ['Alaric I'],
#  ['Alaric II'],
#  ['Alcaeus of Mytilene'],
#  ['Alcidamas'],
#  ['Ealdred (archbishop of York)'],
#  ['Alexander II of Scotland'],
#  ['Alexander I of Serbia'],
#  ['Alexander III of Scotland'],
#  ['Alexander of Greece (disambiguation)'],
#  ['Alexander II'],
#  ['Alexander Aetolus'],
#  ['Alexander Jannaeus'],
#  ['Alexios II Komnenos'],
#  ['Alexios III Angelos'],
#  ['Andrew Jackson'],
#  ['Aleksandr Solzhenitsyn'],
#  ['Aquaculture'],
#  ['Alfred the Great'],
#  ['Algiers'],
#  ['Ibn al-Haytham'],
#  ['Alessandro Allori'],
#  ['Almoravid dynasty'],
#  ['Aloe'],
#  ['Age of consent'],
#  ['Alypius of Antioch'],
#  ['Amalric of Bena'],
#  ['Afonso III of Portugal'],
#  ['Afonso VI of Portugal'],
#  ['Alfonso XII of Spain'],
#  ['Alfonso V of Aragon'],
#  ['Amathus'],
#  ['Alfonso IV'],
#  ['Amazons'],
#  ['Amazon River'],
#  ['Alfred of Beverley'],
#  ['April 22'],
#  ['Ambrosians'],
#  ['Ammon'],
#  ['Ammonius Saccas'],
#  ['Book of Amos'],
#  ['Amram'],
#  ['Anah'],
#  ['Ananda'],
#  ['Anaxagoras'],
#  ['Anaximenes of Lampsacus'],
#  ['Anastasius'],
#  ['Andrew II of Hungary'],
#  ['An Enquiry Concerning Human Understanding'],
#  ['André de Longjumeau'],
#  ['Andriscus'],
#  ['Andronikos I Komnenos'],
#  ['Andronicus of Rhodes'],
#  ['Andronicus'],
#  ['Ammianus Marcellinus'],
#  ['Apollo 13'],
#  ['April 2'],
#  ['Acetylene'],
#  ['Alfred'],
#  ['Apuleius'],
#  ['Anti-ballistic missile'],
#  ['Acre'],
#  ['Arnold Schwarzenegger'],
#  ['Amway'],
#  ['Adam Smith'],
#  ['April 23'],
#  ['Allomorph'],
#  ['Allophone'],
#  ['Affix'],
#  ['Allegory'],
#  ['Allotropy'],
#  ['Alternative medicine'],
#  ['Archimedean solid'],
#  ['Arizona State University'],
#  ['April 14'],
#  ['Alarums and Excursions'],
#  ['Alfonso Jordan'],
#  ['American English'],
#  ['Albert Spalding'],
#  ['Australian English'],
#  ['American Airlines Flight 77'],
#  ['Allele'],
#  ['Ampicillin'],
#  ['Antimicrobial resistance'],
#  ['Antigen'],
#  ['Antwerp (disambiguation)'],
#  ['Aquila'],
#  ['Argo Navis'],
#  ['Antlia'],
#  ['Ara (constellation)'],
#  ['Arkansas'],
#  ['Andrew Carnegie'],
#  ['Aeon'],
#  ['Australian Democrats'],
#  ['American Civil Liberties Union'],
#  ['Alexander Technique'],
#  ['Apollo 1'],
#  ['Apollo 10'],
#  ['Apollo 12'],
#  ['April 17'],
#  ['Alpha Centauri'],
#  ['Amiga'],
#  ['Actinophryid'],
#  ['Algebraic geometry'],
#  ['Austin, Texas'],
#  ['Argument from morality'],
#  ['Auschwitz concentration camp'],
#  ['A. J. Ayer'],
#  ['André Weil'],
#  ['Achaeans (Homer)'],
#  ['Augustine of Hippo'],
#  ['Acting'],
#  ['Advance Australia Fair'],
#  ['Automatic number announcement circuit'],
#  ['Auguste Rodin'],
#  ['Ann Arbor, Michigan'],
#  ['Act of Settlement 1701'],
#  ['Aircraft hijacking'],
#  ['Auguste and Louis Lumière'],
#  ['Acts of the Apostles'],
#  ['Aphasia'],
#  ['Andrew Tridgell'],
#  ['Asterix'],
#  ['Heathenry in the United States'],
#  ['Adalbert of Prague'],
#  ['Apple II series'],
#  ['Apple III'],
#  ['AVL tree'],
#  ['Astrology'],
#  ['Ark of the Covenant'],
#  ['Arthur Wellesley'],
#  ['Atlanta Braves'],
#  ['Atari ST'],
#  ['Armour'],
#  ['Armoured fighting vehicle'],
#  ['Anton Drexler'],
#  ['Artistic License'],
#  ['ABCD'],
#  ['Anti-realism'],
#  ['Arsenal F.C.'],
#  ['Cuisine of the United States'],
#  ['Ahmad Shah Massoud'],
#  ['Armadillo'],
#  ['August 11'],
#  ['Arcology'],
#  ['April 5'],
#  ['April 19'],
#  ['Amstrad CPC'],
#  ['Arabic alphabet'],
#  ['Arctic fox'],
#  ['Aircraft carrier'],
#  ['Apicomplexa'],
#  ['Argentine cuisine'],
#  ['April 8'],
#  ['Ad hominem'],
#  ['Antipope John XXIII'],
#  ['Annapolis Valley'],
#  ['Apostolic succession'],
#  ['List of Anglo-Saxon monarchs and kingdoms'],
#  ['Apple II'],
#  ['April 3'],
#  ['Alexis Korner'],
#  ['Tank destroyer'],
#  ['Armored car (military)'],
#  ['Self-propelled anti-aircraft weapon'],
#  ['American Media, Inc.'],
#  ['Aramaic language'],
#  ['Actinide'],
#  ['Arthur Miller'],
#  ['Anton Diabelli'],
#  ['Audio file format'],
#  ['Area 51'],
#  ["Amdahl's law"],
#  ['Abbe number'],
#  ['Rise and Fall of the City of Mahagonny'],
#  ['Archbishop of Canterbury'],
#  ['Abstract data type'],
#  ['American Football League'],
#  ['Abu Nidal Organization'],
#  ['Alessandro Scarlatti'],
#  ['Albert Pike'],
#  ['Accelerated Graphics Port'],
#  ['Aalen'],
#  ['Antidepressant'],
#  ['Auger effect'],
#  ['Analog television'],
#  ['Adhesive'],
#  ['Aon (company)'],
#  ['Alban Berg'],
#  ['A cappella'],
#  ['Arrangement'],
#  ['Athanasian Creed'],
#  ['Ann Widdecombe'],
#  ['Aurangzeb'],
#  ['Minute and second of arc'],
#  ['Alberto Giacometti'],
#  ['Anton Chekhov'],
#  ['Aarau'],
#  ['Canton of Aargau'],
#  ['Aba'],
#  ['American Quarter Horse'],
#  ['Abadeh'],
#  ['Abakan'],
#  ['Arc de Triomphe'],
#  ['Anthroposophy'],
#  ['Aurochs'],
#  ['Anus'],
#  ['Acantharea'],
#  ['African National Congress'],
#  ['Amphetamine'],
#  ['Asynchronous communication'],
#  ['Artillery'],
#  ['Airbus A300'],
#  ['Articolo 31'],
#  ['Alexander Kerensky'],
#  ['Administrative law'],
#  ['April 10'],
#  ['Arbroath Abbey'],
#  ['Accounting'],
#  ['George Abbot (bishop)'],
#  ['Adware'],
#  ['Aegadian Islands'],
#  ['Aegean civilizations'],
#  ['Aegina'],
#  ['Aegisthus'],
#  ['Atomic absorption spectroscopy'],
#  ['Arthur St. Clair'],
#  ['Ajaccio'],
#  ['Ajmer'],
#  ['Ajmer-Merwara'],
#  ['Abatement of freehold'],
#  ['Affiliation (family law)'],
#  ['Affray'],
#  ['Abbahu'],
#  ['Abd al-Rahman I'],
#  ['Abd-ar-Rahman III'],
#  ['Abd ar-Rahman IV'],
#  ['Abdülaziz'],
#  ['Abdera, Spain'],
#  ['Apollos'],
#  ['Antacid'],
#  ['Abdur Rahman Khan'],
#  ['Aberdare'],
#  ['Aberration of light'],
#  ['Optical aberration'],
#  ['Aberdeen, South Dakota'],
#  ['Aberdour'],
#  ['Anders Celsius'],
#  ['Adam Carolla'],
#  ['Autocorrelation'],
#  ['Atlas Autocode'],
#  ['Abiathar'],
#  ['Azad Kashmir'],
#  ['Alkene'],
#  ['Alkyne'],
#  ['ACE inhibitor'],
#  ['Antianginal'],
#  ['Anatomical Therapeutic Chemical Classification System'],
#  ['Atari 2600'],
#  ['Atari 5200'],
#  ['Atari Jaguar'],
#  ['Atari Lynx'],
#  ['Andrei Sakharov'],
#  ['Astrobiology'],
#  ['Air show'],
#  ['Akihabara'],
#  ['Aron Nimzowitsch'],
#  ['Aragonese language'],
#  ['Advanced Mobile Phone System'],
#  ['Andreas Schlüter'],
#  ['Ash'],
#  ['Antiderivative'],
#  ['Abingdon'],
#  ['Abjuration'],
#  ['Angular momentum'],
#  ['Aung San Suu Kyi'],
#  ['Abraham Joshua Heschel'],
#  ['Latin American Integration Association'],
#  ['Advertising'],
#  ['Andrzej Sapkowski'],
#  ['Ammeter'],
#  ['Antipsychotic'],
#  ['Augustine of Canterbury'],
#  ['Amoxicillin'],
#  ['Alex Lifeson'],
#  ['File archiver'],
#  ['Artemis'],
#  ['Arbeit macht frei'],
#  ['Albinism'],
#  ['AIM (software)'],
#  ['ANS'],
#  ['Interior Alaska'],
#  ['And did those feet in ancient time'],
#  ['The Bush (Alaska)'],
#  ['Ariel Sharon'],
#  ['Anoa'],
#  ['Agner Krarup Erlang'],
#  ['Alcopop'],
#  ['Alkali'],
#  ['AMOS (programming language)'],
#  ['Arcadia 2001'],
#  ['Assassination'],
#  ['Anti-Ballistic Missile Treaty'],
#  ['Austria-Hungary'],
#  ['Admiralty'],
#  ['Ann Druyan'],
#  ['Ambrose of Alexandria'],
#  ['Anubis'],
#  ['Arthur Jensen'],
#  ['Adoptionism'],
#  ['Acid–base reaction'],
#  ['Abu al-Faraj al-Isfahani'],
#  ['Amyl nitrite'],
#  ['Autumn'],
#  ['Alameda, California'],
#  ['Accrington'],
#  ['Armageddon'],
#  ['Muslim conquests of Afghanistan'],
#  ['Alexandria'],
#  ['Alexandria Troas'],
#  ['Alexandria, Romania'],
#  ['Akira Toriyama'],
#  ['Epsilon Ursae Majoris'],
#  ['Amiga 500'],
#  ['Asymptote'],
#  ['Accumulator (computing)'],
#  ['Arithmetic'],
#  ['Amakusa'],
#  ['Adolphe Sax'],
#  ['Aspirated consonant'],
#  ["A Doll's House"],
#  ['AIM-7 Sparrow'],
#  ['AIM-120 AMRAAM'],
#  ['AGM-88 HARM'],
#  ['AIM-54 Phoenix'],
#  ['Lockheed AC-130'],
#  ['Alternative'],
#  ['ANSI C'],
#  ['Alien and Sedition Acts'],
#  ['Ascending chain condition'],
#  ['Adin Steinsaltz'],
#  ['A. E. Housman'],
#  ['Al Capone'],
#  ['Army of Darkness'],
#  ['RUR-5 ASROC'],
#  ['Athanasius of Alexandria'],
#  ['Azores'],
#  ['Outback'],
#  ['Acceptance testing'],
#  ['National Alliance (Italy)'],
#  ['Albert III, Duke of Saxony'],
#  ['Brass'],
#  ['Bonn'],
#  ['The Birth of a Nation'],
#  ['Baltic Sea'],
#  ['Belgium'],
#  ['Blues'],
#  ['Bluegrass'],
#  ['Bar (disambiguation)'],
#  ['Bit'],
#  ['Boron nitride'],
#  ['Bach (disambiguation)'],
#  ['Blood on the Tracks'],
#  ['Love and Theft (Bob Dylan album)'],
#  ['Black Sea'],
#  ['British Columbia'],
#  ['Gautama Buddha'],
#  ['Bridge'],
#  ['Beadwork'],
#  ['Branchiopoda'],
#  ['Baruch Spinoza'],
#  ['Being'],
#  ['...Baby One More Time (album)'],
#  ['Bryozoa'],
#  ['Basis'],
#  ['Beavis and Butt-Head'],
#  ['Bromeliales'],
#  ['Brassicales'],
#  ['Symphony No. 9 (Beethoven)'],
#  ['Piano Trios, Op. 70 (Beethoven)'],
#  ['Violin Sonata No. 5 (Beethoven)'],
#  ['Barratry (common law)'],
#  ['Cue sports'],
#  ['Barbados'],
#  ['Bassas da India'],
#  ['Belarus'],
#  ['Belize'],
#  ['Benin'],
#  ['Bolivia'],
#  ['Botswana'],
#  ['Government of Barbados'],
#  ['Telecommunications in Belgium'],
#  ['Geography of Botswana'],
#  ['Transport in Botswana'],
#  ['Politics of Brazil'],
#  ['Transport in Brazil'],
#  ['Brazilian Armed Forces'],
#  ['Economy of Bulgaria'],
#  ['Transport in Bulgaria'],
#  ['Military of Burkina Faso'],
#  ['Military of Burundi'],
#  ['Bell (disambiguation)'],
#  ['Bell Labs'],
#  ['Bjarne Stroustrup'],
#  ['Brain'],
#  ['Bass music'],
#  ['Bhangra (music)'],
#  ['Beastie Boys'],
#  ['British Isles'],
#  ['Björn Ulvaeus'],
#  ['Benny Andersson'],
#  ['Bluetooth'],
#  ['Blade Runner'],
#  ['Bill Gates'],
#  ['Belgian Blue'],
#  ['Boron'],
#  ['Bromine'],
#  ['Bavaria'],
#  ['BMW'],
#  ['Bay (disambiguation)'],
#  ['Book'],
#  ['Bille August'],
#  ['Bitola'],
#  ['Brassicaceae'],
#  ['At bat'],
#  ['Hit by pitch'],
#  ['Hit (baseball)'],
#  ['On-base percentage'],
#  ['Sacrifice fly'],
#  ['On-base plus slugging'],
#  ['Stolen base'],
#  ['Games played'],
#  ['Binary'],
#  ['Bumin Qaghan'],
#  ['Bilge Khagan'],
#  ['Bauhaus'],
#  ['Bruce Sterling'],
#  ['Banjo'],
#  ['Baseball'],
#  ['History of baseball in the United States'],
#  ['Major League Baseball Rookie of the Year Award'],
#  ['National League Championship Series'],
#  ['American League Championship Series'],
#  ['American League Division Series'],
#  ['2001 World Series'],
#  ['Bruce Perens'],
#  ['British and Irish Lions'],
#  ['Basketball'],
#  ['Ball'],
#  ['Binary relation'],
#  ['Blowfish (cipher)'],
#  ['Biochemistry'],
#  ['Baroque'],
#  ['Boolean algebra (structure)'],
#  ['British'],
#  ['Beachcomber (pen name)'],
#  ['Bodhisattva'],
#  ['Buckingham Palace'],
#  ['British Airways'],
#  ['Bicycling'],
#  ['Biopolymer'],
#  ['Book of Mormon'],
#  ['Blackjack'],
#  ['Bicarbonate'],
#  ['Benjamin Franklin'],
#  ['Bram Stoker'],
#  ['Boat'],
#  ['Blood'],
#  ['Benoit Mandelbrot'],
#  ['Beaumarchais'],
#  ['Bing Crosby'],
#  ['Basel Convention'],
#  ['BASIC'],
#  ['List of Byzantine emperors'],
#  ['Butterfly effect'],
#  ['Buckminster Fuller'],
#  ['Bill Watterson'],
#  ['Black'],
#  ['Bletchley Park'],
#  ['BCPL'],
#  ['Battleship'],
#  ['Battlecruiser'],
#  ['Bob Hawke'],
#  ['Baldr'],
#  ['Brísingamen'],
#  ['Bragi'],
#  ['Blaise Pascal'],
#  ['Binary prefix'],
#  ['BPP (complexity)'],
#  ['BQP'],
#  ['Bartolomeo Ammannati'],
#  ['Bordeaux'],
#  ['Puzzle Bobble'],
#  ['Bone'],
#  ['Bretwalda'],
#  ['Brouwer fixed-point theorem'],
#  ['Benzoic acid'],
#  ['Bouldering'],
#  ['B roll'],
#  ['Bus'],
#  ['Brown University'],
#  ['Bertrand Russell'],
#  ['Boeing 767'],
#  ['Babe Ruth'],
#  ['British English'],
#  ['Battle'],
#  ['Botany'],
#  ['Common buzzard'],
#  ['Barbara Olson'],
#  ["Barnard's Star"],
#  ['Baltic languages'],
#  ['North American B-25 Mitchell'],
#  ['Barry Lyndon'],
#  ['Buffy the Vampire Slayer (film)'],
#  ['Berthe Morisot'],
#  ['Barnard College'],
#  ['Order of Saint Benedict'],
#  ['Bayezid I'],
#  ['Bowls'],
#  ['Barcelonnette'],
#  ["Bahá'í Faith"],
#  ['Belle and Sebastian'],
#  ['Bodhidharma'],
#  ['Baltimore Ravens'],
#  ['Bocce'],
#  ['Bethlehem'],
#  ['Books of Chronicles'],
#  ['Binary tree'],
#  ['Backgammon'],
#  ['Book of Ezra'],
#  ['Batman'],
#  ['Baltimore Orioles'],
#  ['Bohemia'],
#  ['Backplane'],
#  ['Battle of Waterloo'],
#  ['Boomerang'],
#  ['Biological warfare'],
#  ['Book of Isaiah'],
#  ['Bilinear map'],
#  ['Blind Blake'],
#  ['Brian Lara'],
#  ['Beagle'],
#  ['Barry Bonds'],
#  ['Book of Numbers'],
#  ['Book of Revelation'],
#  ['Book of Ruth'],
#  ['Rail transport in Great Britain'],
#  ['British Rail'],
#  ['Book of Proverbs'],
#  ['Book of Ezekiel'],
#  ['Bristol City F.C.'],
#  ['Bioterrorism'],
#  ['Northrop Grumman B-2 Spirit'],
#  ['Bear'],
#  ['Bald eagle'],
#  ['Brown bear'],
#  ['Biathlon'],
#  ['Bubble and squeak'],
#  ['Breast reconstruction'],
#  ['Brownian motion'],
#  ['Bandy'],
#  ['Booker Prize'],
#  ['Book of Hosea'],
#  ['Book of Obadiah'],
#  ['Book of Jonah'],
#  ['Book of Micah'],
#  ['Book of Haggai'],
#  ['Book of Malachi'],
#  ['Book of Zechariah'],
#  ['Book of Zephaniah'],
#  ['Backward compatibility'],
#  ['Blue crane'],
#  ['Billy Bob Thornton'],
#  ['The Big O'],
#  ['The Beach Boys'],
#  ['Beatrix Potter'],
#  ['Bakelite'],
#  ['Bean'],
#  ['Breast'],
#  ['Baghdad'],
#  ['British thermal unit'],
#  ['Band'],
#  ['Battle of Poitiers'],
#  ['Bongo (antelope)'],
#  ['Banshee'],
#  ['Borneo'],
#  ['Ballpoint pen'],
#  ['Brick'],
#  ['Béla Bartók'],
#  ['Bill Haley'],
#  ['Northern bobwhite'],
#  ['Bipolar disorder'],
#  ['Blitz'],
#  ['Balts'],
#  ['Bra–ket notation'],
#  ['Blind Willie McTell'],
#  ['BDSM'],
#  ['Bikini'],
#  ['Bernard of Clairvaux'],
#  ['Braveheart'],
#  ['Brian Aldiss'],
#  ['Bambara language'],
#  ['Baku'],
#  ['Balalaika'],
#  ['Bank of China Tower (Hong Kong)'],
#  ['Ballad'],
#  ['Blue Öyster Cult'],
#  ['Battery Park City'],
#  ['Bacterial vaginosis'],
#  ['Bud Selig'],
#  ['Bison'],
#  ['Basic Role-Playing'],
#  ['Wireless broadband'],
#  ['Björn Borg'],
#  ['Battle of the Nile'],
#  ['Barnabas'],
#  ['Birka'],
#  ['Battle of Agincourt'],
#  ['Bronze Age'],
#  ['BBC News (TV channel)'],
#  ['Bill Oddie'],
#  ['Broadway (Manhattan)'],
#  ['Beta decay'],
#  ['Blitzkrieg'],
#  ['Bee'],
#  ['Basques'],
#  ['Bookkeeping'],
#  ['Bézier curve'],
#  ['Banach algebra'],
#  ['Bruce Campbell'],
#  ['Baron Aberdare'],
#  ['Boy band'],
#  ['B-tree'],
#  ['Big Apple'],
#  ['Berber languages'],
#  ['Brahui language'],
#  ['Boolean satisfiability problem'],
#  ['Bob Jones University'],
#  ['British Empire'],
#  ['Batman Returns'],
#  ['Batman & Robin (film)'],
#  ['Brownie McGhee'],
#  ['Bayonne'],
#  ['Baudot code'],
#  ['Blu Tack'],
#  ['Bacillus'],
#  ['Blue Streak (missile)'],
#  ['Bestiary'],
#  ['Brit milah'],
#  ['British Standards'],
#  ['Branch Davidians'],
#  ['Benzodiazepine'],
#  ['Body mass index'],
#  ['Bladder (disambiguation)'],
#  ['Babylon 5'],
#  ['Balance of trade'],
#  ['Balfour Declaration of 1926'],
#  ['Balfour Declaration'],
#  ['Balkans'],
#  ['Barış Manço'],
#  ['Blitz BASIC'],
#  ['Blood alcohol content'],
#  ['Budweiser'],
#  ['Basso continuo'],
#  ['Borough'],
#  ['Bodmin Moor'],
#  ['Berkeley, California'],
#  ['Bengal'],
#  ['Roman Breviary'],
#  ['B. F. Skinner'],
#  ['Bill'],
#  ['Bill Macy'],
#  ['Bin Laden (disambiguation)'],
#  ['Blizzard Entertainment'],
#  ['Robert Bellarmine'],
#  ['Bildungsroman'],
#  ['Bachelor'],
#  ['British Army'],
#  ['Bob Costas'],
#  ['Beta sheet'],
#  ['Black Russian'],
#  ['Bacardi'],
#  ['Bunsen burner'],
#  ['Blue whale'],
#  ['Bolsheviks'],
#  ['Basic English'],
#  ['Brass instrument'],
#  ['Blood libel'],
#  ['Bagpuss'],
#  ['Born again'],
#  ['Book of Common Prayer'],
#  ['Bovril'],
#  ['Benjamin D. Santer'],
#  ['Bubble Bobble'],
#  ['Blackwood convention'],
#  ['Bill Bixby'],
#  ['Bronze Star Medal'],
#  ['Ballarat'],
#  ['Battle of Abritus'],
#  ['Battle of Berestechko'],
#  ['Brezhnev Doctrine'],
#  ['Brabham'],
#  ['Boeing B-17 Flying Fortress'],
#  ['Bathyscaphe Trieste'],
#  ['Battle of Actium'],
#  ['Bistability'],
#  ['Banda Islands'],
#  ['B.F. Skinner'],
#  ['Bo Diddley'],
#  ['List of Olympic medalists in biathlon'],
#  ['Biathlon World Championships'],
#  ['Inedia'],
#  ['Belfast'],
#  ['Biotite'],
#  ['Burns supper'],
#  ['Bill Bryson'],
#  ['Bentley'],
#  ['Chordate'],
#  ['Chess'],
#  ['Charlie Chaplin'],
#  ['Country'],
#  ['Combinatorics'],
#  ['Calculus'],
#  ['Chemistry'],
#  ['Cytoplasm'],
#  ['Central Europe'],
#  ['Politics of Canada'],
#  ['Computer-generated art'],
#  ['Computing'],
#  ['Casino'],
#  ['Khmer language'],
#  ['Carnivora'],
#  ['Citizen Kane'],
#  ['Callitrichidae'],
#  ['Cebidae'],
#  ['Coast'],
#  ['Cipher'],
#  ['Lists of universities and colleges'],
#  ['Constitution'],
#  ['Common law'],
#  ['Civil law'],
#  ['Court of appeals (disambiguation)'],
#  ['Constellation'],
#  ['Car (disambiguation)'],
#  ['Printer (computing)'],
#  ['Catalan language'],
#  ['Computer games'],
#  ['Collectable card games'],
#  ['Conditional'],
#  ['Cone (disambiguation)'],
#  ['Personal computer hardware'],
#  ['The Consolation of Philosophy'],
#  ['Charlemagne'],
#  ['Czechoslovakia'],
#  ['Computer science'],
#  ['Creationism'],
#  ['Demographics of Chad'],
#  ['Telecommunications in Chad'],
#  ['Transport in Chad'],
#  ['Foreign relations of Chad'],
#  ['Colloid'],
#  ['Cooking'],
#  ['Casino game'],
#  ['Cambrian'],
#  ['Contraception'],
#  ['Physical cosmology'],
#  ['Inflation (cosmology)'],
#  ['Candela'],
#  ['Condensed matter physics'],
#  ['Conversion of units'],
#  ['Chives'],
#  ['Chris Morris (satirist)'],
#  ['Colorado'],
#  ['Carboniferous'],
#  ['California'],
#  ['Columbia River'],
#  ['Commelinales'],
#  ['Coin collecting'],
#  ['Capcom'],
#  ['Demographics of Cambodia'],
#  ['Politics of Cambodia'],
#  ['Transport in Cambodia'],
#  ['Geography of Cape Verde'],
#  ['Politics of Cape Verde'],
#  ['Foreign relations of Cape Verde'],
#  ['Cayman Islands'],
#  ['Central African Republic'],
#  ['Central African Armed Forces'],
#  ['Foreign relations of the Central African Republic'],
#  ['Chile'],
#  ['Foreign relations of Chile'],
#  ['Conspiracy theory'],
#  ['History of Costa Rica'],
#  ...]

# %%
from torch_geometric.data import Data
data = Data(x=x, edge_index=edge_index, titles=titles)

# %%
file_path = "Wiki_en_small_MHRWS_1M_wtitles.pt"
torch.save(data, file_path)
